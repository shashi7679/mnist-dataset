# %%
from sklearn import datasets,svm,metrics
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import numpy as np
from skimage import data,color,transform
import seaborn as sns
import pandas as pd

# %%
digits = datasets.load_digits()

# %%
images = digits.images
print(type(images))#images are already flattened
print(images.shape)
# Out:
# <class 'numpy.ndarray'>
# (1797, 8, 8)

# %%
n_samples = len(digits.images)
data = digits.images.reshape((n_samples, -1))
print(data.shape)
print(type(data))
# Out:
# (1797, 64)
# <class 'numpy.ndarray'>

# %%
#for i in range(10):
    #plt.matshow(transform.resize(digits.images[i],(8,8)))

# %% [markdown]
# **When we reszie our sample images from 8X8 to 64X64**

# %%
def Img64X64(gamma_user):
    resized_image64=[]
    for i in digits.images:
        resized_image64.append(transform.rescale(i,8,anti_aliasing=False))
    resized_image64 = np.array(resized_image64)
    data = resized_image64.reshape((n_samples,-1))
    classifier = svm.SVC(gamma=gamma_user)
    X_train64,X_test64,Y_train64,Y_test64 = train_test_split(data,digits.target,test_size=0.3,shuffle=False)
    X_test64,X_val64,Y_test64,Y_val64 = train_test_split(X_test64,Y_test64,test_size=0.5,shuffle=False)
    classifier.fit(X_train64,Y_train64)
    pred64_val = classifier.predict(X_val64)
    acc64_val = metrics.accuracy_score(Y_val64,pred64_val)
    pred64 = classifier.predict(X_test64)
    acc64 = metrics.accuracy_score(Y_test64,pred64)
    return acc64_val*100,acc64*100

# %% [markdown]
# **When we reszie our sample images from 8X8 to 32X32**

# %%
def Img32X32(gamma_user):
    resized_image32=[]
    for i in digits.images:
        resized_image32.append(transform.resize(i,(32,32),anti_aliasing=False))
    resized_image32 = np.array(resized_image32)
    data = resized_image32.reshape((n_samples,-1))
    classifier32 = svm.SVC(gamma=gamma_user)
    X_train32,X_test32,Y_train32,Y_test32 = train_test_split(data,digits.target,train_size=0.7,shuffle=False)
    X_test32,X_val32,Y_test32,Y_val32 = train_test_split(X_test32,Y_test32,test_size=0.5,shuffle=False)
    classifier32.fit(X_train32,Y_train32)
    pred32_val = classifier32.predict(X_val32)
    acc32_val = metrics.accuracy_score(Y_val32,pred32_val)
    pred32 = classifier32.predict(X_test32)
    acc32 = metrics.accuracy_score(Y_test32,pred32)
    return acc32_val*100,acc32*100

# %%
def Img16X16(gamma_user):
    resized_image16=[]
    for i in digits.images:
        resized_image16.append(transform.resize(i,(16,16),anti_aliasing=False))
    resized_image16 = np.array(resized_image16)
    data = resized_image16.reshape((n_samples,-1))
    classifier16 = svm.SVC(gamma=gamma_user)
    X_train16,X_test16,Y_train16,Y_test16 = train_test_split(data,digits.target,train_size=0.7,shuffle=False)
    X_test16,X_val16,Y_test16,Y_val16 = train_test_split(X_test16,Y_test16,test_size=0.5,shuffle=False)
    classifier16.fit(X_train16,Y_train16)
    pred16_val = classifier16.predict(X_val16)
    acc16_val = metrics.accuracy_score(Y_val16,pred16_val)
    pred16 = classifier16.predict(X_test16)
    acc16 = metrics.accuracy_score(Y_test16,pred16)
    return acc16_val*100,acc16*100

# %%
def Img8X8(gamma_user):
    resized_image8=[]
    for i in digits.images:
        resized_image8.append(i)
    resized_image8 = np.array(resized_image8)
    data = resized_image8.reshape((n_samples,-1))
    classifier8 = svm.SVC(gamma=gamma_user)
    X_train8,X_test8,Y_train8,Y_test8 = train_test_split(data,digits.target,train_size=0.7,shuffle=False)
    X_test8,X_val8,Y_test8,Y_val8 = train_test_split(X_test8,Y_test8,test_size=0.5,shuffle=False)
    classifier8.fit(X_train8,Y_train8)
    pred8_val = classifier8.predict(X_val8)
    acc8_val = metrics.accuracy_score(Y_val8,pred8_val)
    pred8 = classifier8.predict(X_test8)
    acc8 = metrics.accuracy_score(Y_test8,pred8)
    return acc8_val*100,acc8*100

# %% [markdown]
# **When we reszie our sample images from 8X8 to 4X4**

# %%
def Img4X4(gamma_user):
    resized_image4=[]
    for i in digits.images:
        resized_image4.append(transform.resize(i,(4,4),anti_aliasing=False))
    resized_image4 = np.array(resized_image4)
    data = resized_image4.reshape((n_samples,-1))
    classifier4 = svm.SVC(gamma=gamma_user)
    X_train4,X_test4,Y_train4,Y_test4 = train_test_split(data,digits.target,train_size=0.70,shuffle=False)
    X_test4,X_val4,Y_test4,Y_val4 = train_test_split(X_test4,Y_test4,train_size=0.5,shuffle=False)
    classifier4.fit(X_train4,Y_train4)
    pred4_val = classifier4.predict(X_val4)
    acc4_val = metrics.accuracy_score(Y_val4,pred4_val)
    pred4 = classifier4.predict(X_test4)
    acc4 = metrics.accuracy_score(Y_test4,pred4)
    return acc4_val*100,acc4*100

# %%
print("Accuracy for 64X64 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :- ",Img64X64(0.0001))
print("Accuracy for 64X64 images on 70:15:15 Split and gamma 1 on validation set and test set :- ",Img64X64(1))
print("Accuracy for 64X64 images on 70:15:15 Split and gamma 0.5 on validation set and test set :- ",Img64X64(0.5))
print("Accuracy for 64X64 images on 70:15:15 Split and gamma 0.001 on validation set and test set :- ",Img64X64(0.001))
print("Accuracy for 64X64 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :- ",Img64X64(0.000000001))
print("Accuracy for 64X64 images on 70:15:15 Split and gamma 10 on validation set and test set :- ",Img64X64(10))
print("Accuracy for 64X64 images on 70:15:15 Split and gamma 100 on validation set and test set :- ",Img64X64(100))
# Out:
# Accuracy for 64X64 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :-  (90.0, 98.88888888888889)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 1 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 0.5 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 0.001 on validation set and test set :-  (10.0, 12.592592592592592)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 10 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 100 on validation set and test set :-  (9.62962962962963, 10.0)

# %%
print("Accuracy for 32X32 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :- ",Img32X32(0.0001))
print("Accuracy for 32X32 images on 70:15:15 Split and gamma 1 on validation set and test set :- ",Img32X32(1))
print("Accuracy for 32X32 images on 70:15:15 Split and gamma 0.5 on validation set and test set :- ",Img32X32(0.5))
print("Accuracy for 32X32 images on 70:15:15 Split and gamma 0.001 on validation set and test set :- ",Img32X32(0.001))
print("Accuracy for 32X32 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :- ",Img32X32(0.000000001))
print("Accuracy for 32X32 images on 70:15:15 Split and gamma 10 on validation set and test set :- ",Img32X32(10))
print("Accuracy for 32X32 images on 70:15:15 Split and gamma 100 on validation set and test set :- ",Img32X32(100))
# Out:
# Accuracy for 32X32 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :-  (94.81481481481482, 99.25925925925925)
# Accuracy for 32X32 images on 70:15:15 Split and gamma 1 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 32X32 images on 70:15:15 Split and gamma 0.5 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 32X32 images on 70:15:15 Split and gamma 0.001 on validation set and test set :-  (70.0, 81.48148148148148)
# Accuracy for 32X32 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 32X32 images on 70:15:15 Split and gamma 10 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 32X32 images on 70:15:15 Split and gamma 100 on validation set and test set :-  (9.62962962962963, 10.0)

# %%
print("Accuracy for 16X16 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :- ",Img16X16(0.0001))
print("Accuracy for 16X16 images on 70:15:15 Split and gamma 1 on validation set and test set :- ",Img16X16(1))
print("Accuracy for 16X16 images on 70:15:15 Split and gamma 0.5 on validation set and test set :- ",Img16X16(0.5))
print("Accuracy for 16X16 images on 70:15:15 Split and gamma 0.001 on validation set and test set :- ",Img16X16(0.001))
print("Accuracy for 16X16 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :- ",Img16X16(0.000000001))
print("Accuracy for 16X16 images on 70:15:15 Split and gamma 10 on validation set and test set :- ",Img16X16(10))
print("Accuracy for 16X16 images on 70:15:15 Split and gamma 100 on validation set and test set :- ",Img16X16(100))
# Out:
# Accuracy for 16X16 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :-  (92.22222222222223, 95.55555555555556)
# Accuracy for 16X16 images on 70:15:15 Split and gamma 1 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 16X16 images on 70:15:15 Split and gamma 0.5 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 16X16 images on 70:15:15 Split and gamma 0.001 on validation set and test set :-  (93.7037037037037, 99.25925925925925)
# Accuracy for 16X16 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 16X16 images on 70:15:15 Split and gamma 10 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 16X16 images on 70:15:15 Split and gamma 100 on validation set and test set :-  (9.62962962962963, 10.0)

# %%
print("Accuracy for 8X8 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :- ",Img8X8(0.0001))
print("Accuracy for 8X8 images on 70:15:15 Split and gamma 1 on validation set and test set :- ",Img8X8(1))
print("Accuracy for 8X8 images on 70:15:15 Split and gamma 0.5 on validation set and test set :- ",Img8X8(0.5))
print("Accuracy for 8X8 images on 70:15:15 Split and gamma 0.001 on validation set and test set :- ",Img8X8(0.001))
print("Accuracy for 8X8 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :- ",Img8X8(0.000000001))
print("Accuracy for 8X8 images on 70:15:15 Split and gamma 10 on validation set and test set :- ",Img8X8(10))
print("Accuracy for 8X8 images on 70:15:15 Split and gamma 100 on validation set and test set :- ",Img8X8(100))
# Out:
# Accuracy for 8X8 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :-  (90.0, 95.55555555555556)
# Accuracy for 8X8 images on 70:15:15 Split and gamma 1 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 8X8 images on 70:15:15 Split and gamma 0.5 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 8X8 images on 70:15:15 Split and gamma 0.001 on validation set and test set :-  (94.81481481481482, 99.25925925925925)
# Accuracy for 8X8 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 8X8 images on 70:15:15 Split and gamma 10 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 8X8 images on 70:15:15 Split and gamma 100 on validation set and test set :-  (9.62962962962963, 10.0)

# %%
print("Accuracy for 4X4 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :- ",Img4X4(0.0001))
print("Accuracy for 4X4 images on 70:15:15 Split and gamma 1 on validation set and test set :- ",Img4X4(1))
print("Accuracy for 4X4 images on 70:15:15 Split and gamma 0.5 on validation set and test set :- ",Img4X4(0.5))
print("Accuracy for 4X4 images on 70:15:15 Split and gamma 0.001 on validation set and test set :- ",Img4X4(0.001))
print("Accuracy for 4X4 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :- ",Img4X4(0.000000001))
print("Accuracy for 4X4 images on 70:15:15 Split and gamma 10 on validation set and test set :- ",Img4X4(0.000000001))
print("Accuracy for 4X4 images on 70:15:15 Split and gamma 100 on validation set and test set :- ",Img4X4(0.000000001))
# Out:
# Accuracy for 4X4 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :-  (75.18518518518519, 79.25925925925927)
# Accuracy for 4X4 images on 70:15:15 Split and gamma 1 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 4X4 images on 70:15:15 Split and gamma 0.5 on validation set and test set :-  (10.37037037037037, 12.962962962962962)
# Accuracy for 4X4 images on 70:15:15 Split and gamma 0.001 on validation set and test set :-  (82.22222222222221, 88.88888888888889)
# Accuracy for 4X4 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 4X4 images on 70:15:15 Split and gamma 10 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 4X4 images on 70:15:15 Split and gamma 100 on validation set and test set :-  (9.62962962962963, 10.0)

# %%
x = [0.000000001,0.0001,0.001,0.5,1,10,100]
xi = list(range(len(x)))

# %% [markdown]
# On 4X4 sample images

# %%
y_val4 = [9.629,75.185,82.222,10.370,9.629,9.629,9.629]
plt.ylim(0,100)
plt.plot(xi, y_val4, marker='o',  color='r', label='Square') 
plt.xlabel('gamma')
plt.ylabel('Accuracy(%)') 
plt.xticks(xi, x)
plt.title('Accuracy on Validation set of 4X4 image')
plt.legend() 
plt.show()

# %%
y_test4 = [10.0,79.259,88.888,12.962,10.0,10.0,10.0]
plt.ylim(0,100)
plt.plot(xi, y_test4, marker='o',  color='r', label='Square') 
plt.xlabel('gamma')
plt.ylabel('Accuracy(%)') 
plt.xticks(xi, x)
plt.title('Accuracy on Test set of 4X4 image')
plt.legend() 
plt.show()

# %% [markdown]
# For 8X8 sample images

# %%
y_val8 = [9.629,90.0,94.814,9.629,9.629,9.629,9.629]
plt.ylim(0,100)
plt.plot(xi, y_val8, marker='o',  color='r', label='Square') 
plt.xlabel('gamma')
plt.ylabel('Accuracy(%)') 
plt.xticks(xi, x)
plt.title('Accuracy on Validation set of 8X8 image')
plt.legend() 
plt.show()

# %%
y_test8 = [10.0,95.555,99.259,10.0,10.0,10.0,10.0]
plt.ylim(0,100)
plt.plot(xi, y_test8, marker='o',  color='r', label='Square') 
plt.xlabel('gamma')
plt.ylabel('Accuracy(%)') 
plt.xticks(xi, x)
plt.title('Accuracy on Test set of 8X8 image')
plt.legend() 
plt.show()

# %% [markdown]
# For 16X16 sample images

# %%
y_val16 = [9.629,92.222,93.703,9.629,9.629,9.629,9.629]
plt.ylim(0,100)
plt.plot(xi, y_val16, marker='o',  color='r', label='Square') 
plt.xlabel('gamma')
plt.ylabel('Accuracy(%)') 
plt.xticks(xi, x)
plt.title('Accuracy on Validation set of 16X16 image')
plt.legend() 
plt.show()

# %%
y_test16 = [10.0,95.555,99.259,10.0,10.0,10.0,10.0]
plt.ylim(0,100)
plt.plot(xi, y_test16, marker='o',  color='r', label='Square') 
plt.xlabel('gamma')
plt.ylabel('Accuracy(%)') 
plt.xticks(xi, x)
plt.title('Accuracy on Test set of 16X16 image')
plt.legend() 
plt.show()

# %% [markdown]
# For 32X32 sample images

# %%
y_val32 = [9.629,94.814,70.0,9.629,9.629,9.629,9.629]
plt.ylim(0,100)
plt.plot(xi, y_val32, marker='o',  color='r', label='Square') 
plt.xlabel('gamma')
plt.ylabel('Accuracy(%)') 
plt.xticks(xi, x)
plt.title('Accuracy on Validation set of 32X32 image')
plt.legend() 
plt.show()

# %%
y_test32 = [10.0,99.259,81.481,10.0,10.0,10.0,10.0]
plt.ylim(0,100)
plt.plot(xi, y_test32, marker='o',  color='r', label='Square') 
plt.xlabel('gamma')
plt.ylabel('Accuracy(%)') 
plt.xticks(xi, x)
plt.title('Accuracy on Test set of 32X32 image')
plt.legend() 
plt.show()

# %% [markdown]
# For 64X64 Sample Images
# Accuracy for 64X64 images on 70:15:15 Split and gamma 0.0001 on validation set and test set :-  (90.0, 98.88888888888889)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 1 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 0.5 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 0.001 on validation set and test set :-  (10.0, 12.592592592592592)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 0.000000001 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 10 on validation set and test set :-  (9.62962962962963, 10.0)
# Accuracy for 64X64 images on 70:15:15 Split and gamma 100 on validation set and test set :-  (9.62962962962963, 10.0)

# %%
y_val64 = [9.629,90.0,10.0,9.629,9.629,9.629,9.629]
plt.ylim(0,100)
plt.plot(xi, y_val64, marker='o',  color='r', label='Square') 
plt.xlabel('gamma')
plt.ylabel('Accuracy(%)') 
plt.xticks(xi, x)
plt.title('Accuracy on Validation set of 64X64 image')
plt.legend() 
plt.show()

# %%
y_test64 = [10.0,98.888,12.592,10.0,10.0,10.0,10.0]
plt.ylim(0,100)
plt.plot(xi, y_test64, marker='o',  color='r', label='Square') 
plt.xlabel('gamma')
plt.ylabel('Accuracy(%)') 
plt.xticks(xi, x)
plt.title('Accuracy on Test set of 64X64 image')
plt.legend() 
plt.show()
